# %%
from matplotlib import pyplot as plt
import numpy as np
import sympy as sym
import math

# %% [markdown]
# First, we define the value of our **parameters**. We can define here the number of iterations for our algorithm.

# %%
#step size
h=0.1;
#Number of iterations
k=20

# %% [markdown]
# By using the syntax of Python's symbolic maths, we define the differential equation we want to study. We use the variable **dy** to represent y'.
# We must also define an **initial condition**, in the form of a pair of coordinates. We can define several sets of initial coordinates to study different solutions.

# %%
#define our differential equation
x=sym.Symbol('x');
y=sym.Symbol('y');
dy=sym.Symbol('dy');
#We write here the equation we are studying
dy=y+x;

#set of initial conditions
x01=-10;
y01=2;

#other set of initial conditions
x02=-8;
y02=2;

# %% [markdown]
# We now define a function which takes initial conditions as an argument, and produces two **lists of coordinates** obtained from the iterations of Euler's method.

# %%
def processODE(x1,y1):
_ _ _ _ 
    return(L1,L2);

# %% [markdown]
# Now, we **plot the results** of the previous function, for the each set of initial conditions defined above.

# %%
LX1,LY1=processODE(x01,y01);
LX2,LY2=processODE(x02,y02);
plt.plot(LX1,LY1);
plt.plot(LX2,LY2);


plt.show()

# %% [markdown]
# To go a little further, we can now define a function that executes Euler's method with a **range of initial conditions**. For instance, f(0)=-10 to 10 (you can choose a different range and play around). This allows us to visualise the shape of many solutions at once.

# %%
_ _ _ _

# %% [markdown]
# Now that Euler's Method is implemented, we can go back to the beginning and play around. First, try a well-known equation and observe the results.

# %% [markdown]
# You can also try more complicated differential equations and observe the results of Euler's method.
